# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from scripts.data_clean import DataCleaner

# %%
cleaner = DataCleaner()
    
print("--- Loading Data ---")
creditcard_df = cleaner.load_data("../data/raw/Fraud_Data.csv")

    
print("--- Cleaning Data ---")
creditcard_df = cleaner.handle_missing_values(creditcard_df)
creditcard_df = cleaner.remove_duplicates(creditcard_df)
creditcard_df = cleaner.correct_data_types(creditcard_df)
# Out:
# --- Loading Data ---
# --- Cleaning Data ---
